# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# # Working With Pandas Series

# %% [markdown]
# ## a. Creating Series

# %%
pd.__version__
# Out:
# '3.0.1'

# %% [markdown]
# Seires through list

# %%
lst = [1, 2, 3, 4, 5]
print(lst)
# Out:
# [1, 2, 3, 4, 5]
